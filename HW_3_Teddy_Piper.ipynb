# %% [markdown]
# <a href="https://colab.research.google.com/github/Teddypiper12/MIS-2800/blob/main/HW_3_Teddy_Piper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The next six blocks provide the exact code to run to get your Colab file started to run SQLite3

# %%
# Type this code exactly as shown to intall the first library needed for SQLite3 to work using SQLite Magic
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 63.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
#Block 1
# Instructions: There is a typo in the table.  Hint: a word is missing.
# %%sql
CREATE Table Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# -- Instructions: Fix the code to select all the columns
# from the Marketing_Brands table
# %%sql
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# -- Instructions: Fix the code to display only the brand names and
# brand types that had budget over 700000
# %%sql
SELECT brand_name, brand_type
FROM Marketing_Brands
Where brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
#Block 5
# Instructions: Fix the code to find the brand types that are Religious
# %%sql
SELECT brand_type
From Marketing_Brands
Where brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
#Block 6
# -- Instructions: Fix the code to display the
# brand names that have a budget under 1000000
# %%sql
SELECT brand_name
From Marketing_Brands
Where brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
#Block 7
# Instructins: Fix the code so that this will run SQLite3 in
# Colab without having to wrap in Python.  Hint: It's Magic!
# %%sql
Select * From Marketing_Brands
Where brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# Snacks or Beverages.  Display only the brand names.
# %%sql
Select brand_name
From Marketing_Brands
Where brand_type = 'Snacks' or brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
#Block 9
# DESC order. Display only the brand_name and brand_budget.
# %%sql
Select brand_name, brand_budget
From Marketing_Brands
Order By brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.
# %%sql
Select *
From Marketing_Brands
Order By brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# Answer the Questions Below Based on the SQL Code You've Run Above

# %% [markdown]
# 1. How did you fix the error in Block #1? Answer: I added the missing keyword TABLE to the CREATE TABLE statement so the database knows I am creating a new table.
# 2. How did you fix the error in Block #2? Answer: I added the missing phrase INSERT INTO Marketing_Brands so the database knows which table to insert the values into.
# 3. How did you fix the error in Block #3? Answer: I added the asterisk (*) after SELECT so it selects all columns from the table.
# 4. How did you fix the error in Block #4? Answer: 4. How did you fix the error in Block #4?
# I specified the correct columns (brand_name and brand_type) and added a WHERE clause to filter budgets over 700000.
# 5. How did you fix the error in Block #5? Answer: 5. How did you fix the error in Block #5?
# I added the missing WHERE clause to filter for brand_type = 'Religious' and completed the SQL syntax.
# 6. How did you fix the error in Block #6? Answer: 6. How did you fix the error in Block #6?
# I added the missing column (brand_name) and the WHERE condition to filter budgets under 1000000.
# 7. How did you fix the error in Block #7? Answer: 7. How did you fix the error in Block #7?
# I added the missing %%sql magic command so the query runs as SQL instead of Python.
# 8. How did you fix the error in Block #8? Answer: 8. How did you fix the error in Block #8?
# I added the correct WHERE clause using OR to filter for Snacks or Beverages, and selected only the brand names.
# 9. How did you fix the error in Block #9? Answer: 9. How did you fix the error in Block #9?
# I added the missing columns (brand_name, brand_budget) and the ORDER BY ... DESC clause to sort by budget.
# 10. How did you fix the error in Block #10? Answer: 10. How did you fix the error in Block #10?
# I wrote a complete SELECT * FROM ... ORDER BY ... ASC statement to show all columns sorted by budget in ascending order.
